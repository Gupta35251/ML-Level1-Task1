# %% [markdown]
# **Importing Dependencies**

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ***Handling the missing data ***

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Machine Learning Task List /Data Set For Task/2) Stock Prices Data Set.csv')
dataset.head()
# Out:
#   symbol        date      open      high       low     close    volume
# 0    AAL  2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943
# 1   AAPL  2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957
# 2    AAP  2014-01-02  110.3600  111.8800  109.2900  109.7400    542711
# 3   ABBV  2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061
# 4    ABC  2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391

# %%
dataset.shape
# Out:
# (497472, 7)

# %%
dataset.isnull().sum()
# Out:
# symbol     0
# date       0
# open      11
# high       8
# low        8
# close      0
# volume     0
# dtype: int64

# %%
dataset['open'].fillna(dataset['open'].mean(),inplace=True)
# Out:
# <ipython-input-16-aaa8381cff5c>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['open'].fillna(dataset['open'].mean(),inplace=True)

# %%
dataset.isnull().sum()
# Out:
# symbol    0
# date      0
# open      0
# high      8
# low       8
# close     0
# volume    0
# dtype: int64

# %%
dataset['high'].fillna(dataset['high'].median(),inplace=True)
# Out:
# <ipython-input-18-ed209aeb06e0>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['high'].fillna(dataset['high'].median(),inplace=True)

# %%
dataset.isnull().sum()
# Out:
# symbol    0
# date      0
# open      0
# high      0
# low       8
# close     0
# volume    0
# dtype: int64

# %%
dataset=dataset.dropna(how='any')

# %%
dataset.isnull().sum()
# Out:
# symbol    0
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %% [markdown]
# # **Label Encoding**

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Machine Learning Task List /Data Set For Task/2) Stock Prices Data Set.csv')
dataset.head()
# Out:
#   symbol        date      open      high       low     close    volume
# 0    AAL  2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943
# 1   AAPL  2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957
# 2    AAP  2014-01-02  110.3600  111.8800  109.2900  109.7400    542711
# 3   ABBV  2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061
# 4    ABC  2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391

# %%
label_encoder=LabelEncoder()

# %%
label=label_encoder.fit_transform(dataset['symbol'])
dataset['symbol'] = label

# %%
label=label_encoder.fit_transform(dataset['date'])
dataset['date'] = label

# %%
dataset.head()
# Out:
#    symbol  date      open      high       low     close    volume  target
# 0       1     0   25.0700   25.8200   25.0600   25.3600   8998943       1
# 1       3     0   79.3828   79.5756   78.8601   79.0185  58791957       3
# 2       2     0  110.3600  111.8800  109.2900  109.7400    542711       2
# 3       4     0   52.1200   52.3300   51.5200   51.9800   4569061       4
# 4       5     0   70.1100   70.2300   69.4800   69.8900   1148391       5

# %% [markdown]
# **Splitting the data into training data and testing data**

# %%
X=dataset.drop(columns = 'symbol',axis=1)
Y=dataset['symbol']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=3)

# %%
X.shape,X_train.shape,X_test.shape
# Out:
# ((497472, 7), (397977, 7), (99495, 7))

# %% [markdown]
# **Standardizing the data**

# %%
scaler=StandardScaler()

# %%
X_train_standardized=scaler.fit_transform(X_train)

# %%
print(X_train_standardized)
# Out:
# [[ 1.19911586 -0.32787252 -0.32606789 ... -0.3389539  -0.03643765
#   -1.4267239 ]
#  [ 1.56039304 -0.14306455 -0.1468032  ... -0.1430485   0.74027554
#   -0.69990342]
#  [ 1.0855716   0.44145129  0.43448169 ...  0.44080701 -0.4097863
#    1.21999975]
#  ...
#  [-1.19563574  1.77193011  1.77317461 ...  1.78808972 -0.47858073
#   -1.6529982 ]
#  [-0.34233345  0.62754609  0.62218929 ...  0.62354646 -0.31052489
#   -1.45415109]
#  [-1.23692456 -0.21987814 -0.21935336 ... -0.21481778 -0.38198094
#    0.67145599]]

# %%
X_test_standardized=scaler.fit_transform(X_test)

# %%
print(X_test_standardized)
# Out:
# [[-0.65719484 -0.61186767 -0.61239603 ... -0.61261036  0.3744444
#    0.06436609]
#  [ 1.16344027 -0.52905154 -0.5305498  ... -0.52758938 -0.29812079
#    0.03007025]
#  [ 0.41660129  1.51084035  1.52910283 ...  1.53441142 -0.34387343
#   -1.25945357]
#  ...
#  [ 1.03609906 -0.4244417  -0.42843414 ... -0.44314941 -0.29590496
#   -1.21143938]
#  [-0.2235464   0.99738038  0.98274083 ...  0.94313797 -0.26046073
#    0.34559203]
#  [-1.61397472 -0.29048299 -0.28280165 ... -0.28298461 -0.04758168
#   -0.82732591]]
